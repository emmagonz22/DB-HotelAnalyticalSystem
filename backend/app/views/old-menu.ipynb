# %%
# %%html
# <style>
#     .container {
#         margin-top: 20px;
#         height: 80px;
#     }
#     /* Navbar container */
#     .navbar {
#         display: flex;
#         overflow: hidden;
#         background-color: #fff; /* Dark background color */
#         font-family: Arial, sans-serif; /* Change the font-family */
#         height: auto !important;
#         border-radius: 30px;
#         margin-left: 60px;
#         margin-right: 60px;
#         box-shadow: rgba(100, 100, 111, 0.6) 0px 9px 19px 0px;
#     }
#
#     /* Navbar links */
#     .navbar a {
#         width: 100%;
#         font-size: 16px; /* Font size */
#         color: black; /* Text color */
#         text-align: center; /* Centering text */
#         padding: 14px 20px; /* Some padding */
#         text-decoration: none; /* No underline */
#     }
#
#     /* Links - change color on hover */
#     .navbar a:hover {
#         background-color: #0084FF;
#         color: #fff; /* Black text color on hover */
#     }
#
#
# </style>
# <div class="container">
#     <div class="navbar">
#         <a href="/voila/render/home.ipynb">Home</a>
#         <a href="/voila/render/globals.ipynb">Global</a>
#         <a href="/voila/render/locals.ipynb">Locals</a>
#         <a href="/voila/render/about.ipynb">Sign out</a>
#     </div>
# </div>

# %%
username = widgets.Text(description="Username:")
password = widgets.Password(description="Password:")

submit_button = widgets.Button(description="Submit", button_style='success')

output = widgets.Output()

def submit(b):
    with output:
        output.clear_output()
        # Assuming some validation and processing here
        print(f"Username: {username.value}")
        print(f"Password: {password.value}")

#submit_button.on_click(submit)


#display(username, password, submit_button, output)

html_form = """
<script>
</script>
<style>
    @import url('https://fonts.googleapis.com/css2?family=Jersey+25&family=Ubuntu+Sans:ital,wght@0,100..800;1,100..800&display=swap');
    
    .widget-text { display: none; }
    
    .widget-area { display: none; }
    
    .widget-text input[type='text'], .widget-text input[type='password'] {
        display: none;
    }
    
    .container {
        display: flex;
        justify-content: center;
        margin-top: 20px;
        height: 800px;
        width: 100%;
    }
    
    .card-container {
        margin-top: 60px;
        height: 500px;
        width: 450px;
        box-shadow: rgba(100, 100, 111, 0.6) 0px 9px 19px 0px;
    }
    
    .form {
        width: 100%;
    }
    
    .tab{ 
        display: flex;   
        margin-top: 30px;
    }

    #login-form{
        display: block;
        justify-content: center;
        margin: 60px;
    }
    
    .register-form{
        display: none;
        justify-content: center;
        margin: 60px;
    }
    
    .tab-button-login {
        font-family: "Ubuntu Sans", sans-serif;
        font-weight: bold;
        width: 100%;
        height: 30px;
        background-color: #0084FF;
        border: none;
        margin-left: 15px;
        margin-right: 5px;
        border-radius: 30px 30px 30px 30px;
    }
    
    .tab-button-register {
        
        font-family: "Ubuntu Sans", sans-serif;
        font-weight: bold;
        width: 100%;
        height: 30px;
        background-color: #00FF73;
        border: none;
        margin-left: 5px;
        margin-right: 15px;
        border-radius: 0 30px 30px 0; 
    }
    
    .tab-button-login:hover {
        background-color: white;
        color: #0084FF;
    }  
    
    .tab-button-register:hover {
        background-color: white;
        color: #00FF73;
    }
    
    .submit-button {
        font-family: "Ubuntu Sans", sans-serif;
        font-weight: bold;
        width: 200px;
        height: 30px;
        background-color: #00FF73;
        border: none;
        margin-top: 50px;
        margin-left: auto;
        margin-right: auto;
        border-radius: 30px ;
    }
    
    .form__field {
    font-family: inherit;
    width: 100%;
    border: 0;
    border-bottom: 2px solid #9b9b9b;
    outline: 0;
    font-size: 1.3rem;
    
    padding: 7px 0;
    background: transparent;
    border-color: transparent;
    transition: border-color 0.2s;

    &::placeholder {
        color: transparent;
    }

    &:placeholder-shown ~ .form__label {
        font-size: 1.3rem;
        cursor: text;
        top: 20px;
    }
}

.form__label {
  display: block;
  transition: 0.2s;
  font-size: 1rem;
  color: #9b9b9b;
}

.form__field:focus {
  ~ .form__label {
        display: block;
        transition: 0.2s;
        font-size: 1rem;
        color: #0084FF;
        font-weight:700;    
  }
  padding-bottom: 6px;  
  font-weight: 700;
  border-width: 3px;
  border-color: transparent;
  border-image: linear-gradient(to right, #0084FF,#00FF73);
  border-image-slice: 1;
}
/* reset input */
.form__field{
  &:required,&:invalid { box-shadow:none; }
}
.login-label {
    display: flex;
    font-family: "Ubuntu Sans", sans-serif;
    font-weight: bold;
    width: 100%;
    height: 30px;
    background-color: #0084FF;
    border: none;
    margin-left: 15px;
    margin-right: 15px;
    align-content: center;
    align-items: center;
    align-self: center;
    justify-content: center;
    text-align: center;
    border-radius: 15px 15px 15px 15px; 
}
</style>
<div class="container">
    <div class="card-container">
        <div class="tab">
            <div class='login-label'>Login</div>
        </div>
    
        <div class="form">        
            <form id="login-form" method="POST" action="http://localhost:5000/auth">
                
        
                <div>
                    <input type="input" class="form__field" placeholder="Username" name="username" id='username' required />
                    <label for="username" class="form__label">Username</label>
                </div>
           
                <br>
                <br>
                <br>
                <br>
                <div>      
                    <input type="password" class="form__field" placeholder="Password" name="password" id='password' required />
                    <label for="password" class="form__label">Password</label>
                </div>
                <br>
                <div style="display: flex; width: 100%; justify-content: center; position: absolute; bottom: 300px; left: 0;">
                    <input type="submit" class="submit-button"/>
                </div>
                
            </form>

        </div>
    </div>
</div>
<script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js"></script>
<script>
console.log("TEST")
document.getElementById('login-form').addEventListener('submit', function(event) {
event.preventDefault();
fetch('http://localhost:5000/auth', {
    method: 'POST',
    headers: {
        'Content-Type': 'application/json', 
        'Accept': 'application/json'
    },
    body: JSON.stringify({
        username: document.getElementById('username').value,
        password: document.getElementById('password').value
    })
})
.then(response => response.json())
.then(data => {
    console.log(data); 
    if (data.status === 'success') {
        window.location.href = '/index'; 
    } else {
        alert('Login failed: ' + data.message);
    }
})
.catch(error => console.error('Error:', error));

}
</script>

"""
display(HTML(html_form))
