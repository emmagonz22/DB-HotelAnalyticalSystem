# %%
from vois.vuetify import settings
settings.dark_mode      = True
settings.color_first    = '#808dc4'
settings.button_rounded = False
from ipywidgets import widgets, Layout
from IPython.display import display, HTML
import os
import json
from random import randrange

# %%
with open("temp.json", "r") as json_file:
    # Load the JSON data
    data = json.load(json_file)
    # Process the data as needed
os.remove("temp.json")
# Out:
#   Cell In[1], line 3
#     display(%store)
#             ^
# SyntaxError: invalid syntax

# %%
class MainPage():

    def __init__(self):

        self.title = ""

        self.out = widgets.Output()
        self.locals = widgets.Button(description="Locals")
        self.globals = widgets.Button(description="Globals")
        self.hotel = widgets.Button(description="Hotel")
        self.employee = widgets.Button(description="Employee")
        self.client = widgets.Button(description="Client")
        self.chain = widgets.Button(description="Chain")
        self.reserve = widgets.Button(description="Reserve")
        self.room = widgets.Button(description="Room")
        self.room_unavailable = widgets.Button(description="Room unavailable")
        self.room_description = widgets.Button(description="Room description")
        self.login_widget = widgets.Button(description="Login")
        self.sign_out = widgets.Button(description="Sign Out")
        self.text_1 = ''
        self.text_2 = ''
        self.statistics_container = widgets.HBox([]) 

        self.crud_container_1 = widgets.HBox([])
        self.crud_container_2 = widgets.HBox([])
        self.crud_container_3 = widgets.HBox([])
        self.crud_container_4 = widgets.HBox([])


        
        

    def navigate_locals(self, b):
        with self.out:
            with open("temp.json", "w") as json_file:
                # Dump the data to the file
                json.dump(data, json_file)
            self.out.clear_output()
            self.hide_main_page()
            # %run locals.ipynb  

    def navigate_globals(self, b):
        with self.out:
            with open("temp.json", "w") as json_file:
                # Dump the data to the file
                json.dump(data, json_file)
            self.out.clear_output()
            self.hide_main_page()
            # %run globals.ipynb  

    def navigate_hotel(self, b):
        with self.out:
            with open("temp.json", "w") as json_file:
                # Dump the data to the file
                json.dump(data, json_file)
            self.out.clear_output()
            self.hide_main_page()
            # %run hotel.ipynb  

    def navigate_employee(self, b):
        with self.out:
            with open("temp.json", "w") as json_file:
                # Dump the data to the file
                json.dump(data, json_file)
            self.out.clear_output()
            self.hide_main_page()
            # %run employee.ipynb  

    def navigate_chain(self, b):
        with self.out:
            with open("temp.json", "w") as json_file:
                # Dump the data to the file
                json.dump(data, json_file)
            self.out.clear_output()
            self.hide_main_page()
            # %run chain.ipynb  

    def navigate_client(self, b):
        with self.out:
            with open("temp.json", "w") as json_file:
                # Dump the data to the file
                json.dump(data, json_file)
            self.out.clear_output()
            self.hide_main_page()
            # %run client.ipynb  

    def navigate_reserve(self, b):
        with self.out:
            with open("temp.json", "w") as json_file:
                # Dump the data to the file
                json.dump(data, json_file)
            self.out.clear_output()
            self.hide_main_page()
            # %run reserve.ipynb  

    def navigate_room(self, b):
        with self.out:
            with open("temp.json", "w") as json_file:
                # Dump the data to the file
                json.dump(data, json_file)
            self.out.clear_output()
            self.hide_main_page()
            # %run room.ipynb  

    def navigate_room_unavailable(self, b):
        with self.out:
            with open("temp.json", "w") as json_file:
                # Dump the data to the file
                json.dump(data, json_file)
            self.out.clear_output()
            self.hide_main_page()
            # %run room_unavailable.ipynb  

    def navigate_room_description(self, b):
        with self.out:
            with open("temp.json", "w") as json_file:
                # Dump the data to the file
                json.dump(data, json_file)
            self.out.clear_output()
            self.hide_main_page()
            # %run room_description.ipynb  

    def navigate_login_widget(self, b):
        with self.out:
            with open("temp.json", "w") as json_file:
                # Dump the data to the file
                json.dump(data, json_file)
            self.out.clear_output()
            self.hide_main_page()
            # %run login_widget.ipynb  

    def sign_out_redirect(self, b):
        with self.out:
            self.out.clear_output()
            # signout
            self.hide_main_page()
            # %run login.ipynb  
            
    def create_main_page(self):
        

        # Add event listener to buttons
        self.locals.on_click(self.navigate_locals)
        self.globals.on_click(self.navigate_globals)
        self.hotel.on_click(self.navigate_hotel)
        self.employee.on_click(self.navigate_employee)
        self.client.on_click(self.navigate_client)
        self.chain.on_click(self.navigate_chain)
        self.reserve.on_click(self.navigate_reserve)
        self.room.on_click(self.navigate_room)
        self.room_unavailable.on_click(self.navigate_room_unavailable)
        self.room_description.on_click(self.navigate_room_description)
        self.login_widget.on_click(self.navigate_login_widget)
        self.sign_out.on_click(self.sign_out_redirect)

        # TODO: Verify position and display only the stats that are needed
       
        crud_options_1 = [self.reserve]
        crud_options_2 = []
        crud_options_3 = []
        stats = [self.locals]
        if data['position'] == "Administrator":
            stats = [self.locals, self.globals]
            crud_options_1 = [self.reserve, 
                              self.employee,
                              self.client]
            crud_options_2 = [ self.chain,
                               self.hotel,
                               self.room]
            crud_options_3 = [self.room_unavailable,
                              self.room_description,
                              self.login_widget]
        else:
            if data['position'] == "Supervisor":
                crud_options_1 = [self.reserve, self.room_unavailable]
            stats = [self.locals]

        self.statistics_container = widgets.HBox(stats) 

        
        self.crud_container_1 = widgets.HBox(crud_options_1 )

        self.crud_container_2 = widgets.HBox(crud_options_2)

        self.crud_container_3 = widgets.HBox(crud_options_3)

        self.crud_container_4 = widgets.HBox([ 
                            self.sign_out
                            ])

        crud_options = [self.reserve]
        stats = [self.locals, self.globals]
        if data['position'] == "Administrator":
            stats = [self.locals, self.globals]
            crud_options = [self.hotel, self.employee, self.client, self.chain, self.reserve, self.room, self.room_unavailable, self.room_description, self.login_widget]
        else:
            if data['position'] == "Supervisor":
                crud_options = [self.reserve, self.room_unavailable]
            stats = [self.locals]
        self.statistics_container = widgets.HBox(stats) 

        self.crud_container = widgets.HBox(crud_options)



        self.title = widgets.HTML('''
        <style>
            .title {
            text-align: center;
            font-size: 50px;
            font-weight: 550;
            heigth: 100px;
            background-image: linear-gradient(to left, var(--primary) ,var(--text) );
            color: transparent;
            background-clip: text;
           
            }
        </style>
        <h1 class="title">
        Hotel Analytical System - Los Chuletas
        </h1>
        ''')
        display(self.title)


    
        style = """
                <style>
                    :root {
                        --text: #0e0101;
                        --background: #fbc6c6;
                        --primary: #9e0529;
                        --secondary: #ffffff;
                        --accent: #4badf3;
                    }

                    #jp-main-content-panel {
                        border: 2px solid #ccc;  
                        width: 100%;
                        color: white;
                        background-color: var(--background) !important;
                    
                    }
                    .label-style {
                        text-align:center;
                        margin-top: 10px;
                        font-size: 20px;
                    
                    }
                    body {
                        background-color: var(--background) !important;
                    }

                    html {
                        background-color: var(--background) !important;
                    }

                    .widget-hbox{
                        display: flex;
                        justify-content: center;
                        text-align: center;
                    }

                    button {
                        margin: 5px;
                        background-color: var(--background) !important; /* Button color */
                        color: var(--text) !important;
                        height: 100px !important;
                        border-radius: 7px;
                        border-style: solid !important;
                        border-width: 1px !important;
                        border-color: var(--text) !important;
                    }
                    button:hover {
                        background-color: var(--primary) !important; /* Button hover state color */
                        color: var(--secondary) !important;
                        border-style: solid;
                        border-color: var(--secondary) !important;
                        border-width: 1px;
                    }

                 
                  #rendered_cells {
                    background-color: var(--background) !important; /* Light grey background */
                    
                }
              
                    h1{
                        display: flex;
                        height: 100px;
                        padding: 0;
                        margin: 0;
                        justify-content: center;
                        align-items: center;
                        align-self: center;
                        align-content: center;

                    }
                   
                .chuleta-icon {
                    position: fixed;
                    bottom: 0px;
                    right: 30px;
                    width: 100px;
                    height: 100px;
                }

                select {
                    border-radius: 7px !important;   
                }

                option {
                    
                }

                option:hover {
                   
                }

              

                </style>
        """
        display(widgets.HTML(style))

        self.text_1 = widgets.HTML('''
            <div class="label-style"> <strong>Statistics</strong> </div>
        ''')
        
        display(self.text_1)

        display(self.statistics_container)
        
        self.text_2 = widgets.HTML('''
            <div class="label-style"> <strong>Modify data</strong>  </div>
        ''')
        display(self.text_2)
        display(self.crud_container_1, self.crud_container_2, self.crud_container_3, self.crud_container_4)
        
        display(self.out)

    


        
 
    def hide_main_page(self):
        self.title.close()
        self.statistics_container.close()
        self.crud_container_1.close()
        self.crud_container_2.close()
        self.crud_container_3.close()
        self.crud_container_4.close()
        self.text_1.close()
        self.text_2.close()

# %%
if __name__ == "__main__":
    index_page = MainPage()
    index_page.create_main_page()
